# %%
# Stroring and Display:

import re, time
class youtube:
    App_Name="Youtube"
    App_Owner="Google"
    App_Published="2005"
    
    User_details={}
    User_Id=2024000

    def __init__(self,user_name,user_mobile,user_email,user_pwd,user_dob):
        self.user_name=user_name
        self.user_mobile=user_mobile
        self.user_email=user_email
        self.user_pwd=user_pwd
        self.user_dob=user_dob
        self.User_Id+=1
        self.concat_user_details(self.User_Id,self)
    
    @classmethod
    def concat_user_details(cls,user_id,Obj):
        cls.User_details[user_id]= Obj
        print(cls.User_details[user_id].__dict__)
        print(cls.User_details)
    
    

Obj=youtube("balaram",934763098,"Balaram@gmail.com","Balaram@21","03-05-2001")

print(youtube.__dict__)

# %%
# Login and Access:
import re
class Login:
    Contact_us=1800-1234-1432
    user_details={}
    user_id=100

    def __init__(self):
        self.user_id+=1
        self.reg_user=input("Enter Username:")
        self.user_phone=input("Enter Phone Number:")
        self.user_email=input("Enter Email Id:")
        self.user_pwd=input("Enter Password:")
        self.user_details1=[self.reg_user,self.user_phone,self.user_email,self.user_pwd]
        self.user_details[self.user_id]=self.user_details1
        self.login()
        
    def login(self):
        User = input("Enter Username:")
        Pwd = input("Enter Password:")

        if validate_User(Pwd,User):
            print("Login Success !")
        else:
            print("Password is not valid. Please follow the password requirements !")
            self.login()

        def validate_User(Pwd,User):
            pattern= re.compile(r'^(?=.*[A-Z])(?=.*[a-z])(?=.*\d)(?=.*[@$!%*?&])[A-Za-z\d@$!%*?&]{8,}$')
            match = re.search(pattern,Pwd)
            pattern1 = re.compile(r'^[a-zA-Z0-9_]{3,20}$')
            match1 =re.search(pattern1,User)
            return bool(match),bool(match1)
Login()

# %%
# Validating Username & Password:

def login():
    User = input("Enter Username:")
    Pwd = input("Enter Password:")
    if validate_User(Pwd,User):
        print("Login Success !")
        print(User,Pwd)
    else:
        print("Password is not valid. Please follow the password requirements !")
        login()
def validate_User(Pwd,User):
    pattern= re.compile(r'^(?=.*[A-Z])(?=.*[a-z])(?=.*\d)(?=.*[@$!%*?&])[A-Za-z\d@$!%*?&]{8,}$')
    match = re.search(pattern,Pwd)
    pattern1 = re.compile(r'^[a-zA-Z0-9_]{3,20}$')
    match1 =re.search(pattern1,User)
    return bool(match),bool(match1)
        
login()

# %%
# Youtube Demo Without Login :
import re, time
class youtube:
    App_Name="Youtube"
    App_Owner="Google"
    App_Published="2005"
    
    User_details={}
    User_Id=2024000

    def __init__(self,user_name,user_mobile,user_email,user_pwd,user_dob):
        
        self.user_name=user_name
        self.user_mobile=user_mobile
        self.user_email=user_email
        self.user_pwd=user_pwd
        self.user_dob=user_dob
        self.User_Id+=1
        self.concat_user_details(self.User_Id,self)
        # self.login()
        self.main()
        
    
    @classmethod
    def concat_user_details(cls,user_id,Obj1):
        cls.User_details[user_id]= Obj1
        # print(cls.User_details[user_id].__dict__)
        # print(cls.User_details)
    
    def login(self):
        user = input("Enter User Name:")
        if user in self.User_details[self.User_Id].__dict__:
            if user == self.User_details[self.User_Id][self.user_name]:
                Pwd = input("Enter Password:")
                if Pwd in self.User_details[self.User_Id].__dict__:
                    if Pwd == self.User_details[self.User_Id][self.user_pwd]:
                        print("Login Success !")
                        self.main()
                else:
                    print("Enter Valid Password!")
        else:
            print("Enter Valid Username !")

    def main(self):
        print('*'*90,f"Welcome Back {self.user_name} ❤️",'*'*90)
        items=["1. Home","2. Subscriptions","3. Profile","4. Explore","5. More From Youtube","6. Exit"]
        for i in items:
            print(i)
        print("*"*210)
        n = int(input("Choose Your Option:"))
        match n:
            case 1:
                print("You Choosen: Home")
                self.home()
            case 2:
                print("You Choosen: Subscriptions")
                self.Subscription()
            case 3:
                print("You Choosen: Profile")
                self.profile(self)
            case 4:
                print("You Choosen: Explore")
                self.explore()
            case 5:
                print("You Choosen: More From Youtube")
                self.more()
            case 6:
                print("You Choosen: Exit")
                self.exit()
            case _:
                print("Invalid Option...!")
                self.main()
    
    def home(self):
        print("*"*150)
        Videos=[f"Sirivennala - Lyrical Video | SSR | Telugu {"https://www.youtube.com/watch?v=-19EvIcr9ZA&list=TLPQMDMwMTIwMjTcRGiwPFERLA&index=1&pp=gAQBiAQB8AUB"}",
                f"Hi Nanna:Samayama Lyrical Video | Telugu {"https://www.youtube.com/watch?v=8I9v8yaaknM&list=TLPQMDMwMTIwMjTcRGiwPFERLA&index=2&pp=gAQBiAQB8AUB"}",
                f"Neetho Unte Chalu - Video Song | Telugu {"https://www.youtube.com/watch?v=o19q-7-nIyA&list=TLPQMDMwMTIwMjTcRGiwPFERLA&index=3&pp=gAQBiAQB8AUB"}",
                f"Hi Nanna:Ammaadi(lyrical Video) | Telugu {"https://www.youtube.com/watch?v=uQyUcknlZq0&list=TLPQMDMwMTIwMjTcRGiwPFERLA&index=4&pp=gAQBiAQB8AUB"}",
                f"Gang Leader - Hoyna Hoyna Video | Telugu {"https://www.youtube.com/watch?v=91EzD9VgwGk&list=TLPQMDMwMTIwMjTcRGiwPFERLA&index=5&pp=gAQBiAQB8AUB"}",
                f"Rise of Shyam - Video Song | SSR | Telugu {"https://www.youtube.com/watch?v=60P5xR4GxvE&list=TLPQMDMwMTIwMjTcRGiwPFERLA&index=6&pp=gAQBiAQB8AUB"}",
                f"Evvadikevvadu Banisa Video | KGF | Telugu {"https://www.youtube.com/watch?v=ifwEyWSRrUw&list=TLPQMDMwMTIwMjTcRGiwPFERLA&index=7&pp=gAQBiAQB8AUB"}",
                f"Akaashame Nee Haddhu Ra ! Lyric | Telugu {"https://www.youtube.com/watch?v=9zOIUpJLVps&list=TLPQMDMwMTIwMjTcRGiwPFERLA&index=8&pp=gAQBiAQB8AUB"}",
                f"Dum Masala Lyrical Song | GK | Telugu {"https://www.youtube.com/watch?v=uFpDexeZsG8&list=TLPQMDMwMTIwMjTcRGiwPFERLA&index=9&pp=gAQBiAQB8AUB"}"]
        
        for i in Videos:
            print(i)
        print('*'*150)
        self.main()
    
    def Subscription(self):
        print("*"*150)
        Sub=[f"Apna College {"https://www.youtube.com/@ApnaCollegeOfficial"}",
             f"ForntLineMedia {"https://www.youtube.com/@Frontlinesmedia"}",
             f"Neeraj Walia {"https://www.youtube.com/@ezsnippat"}",
             f"MAHARAJA KITCHEN {"https://www.youtube.com/@MAHARAJAKITCHEN07"}",
             f"$4Visions {"https://www.youtube.com/@4visions270"}",
             f"PrepInsta {"https://www.youtube.com/@PrepInsta"}",
             f"CM Concepts {"https://www.youtube.com/@chauhan_maheshh"}"]
        for i in Sub:
            print("Your Subscriptions:")
            print(i)
        print("*"*150)
        self.main()
    
    @classmethod
    def profile(cls,self):
        print("*"*150)
        list=cls.User_details[self.User_Id].__dict__.items()
        for i in list:
            print(i)
        print("*"*150)
    
    def explore(self):
        print("*"*150)
        options=["1. Trending","2. Shopping","3. Music","4. Films","5. Live", "6. Podcasts","7. Return to Menu"]
        for i in options:
            print(i)
        n=int(input("Enter Your Choice:"))
        match n:
            case 1:
                print(f"You Choosen: Trending ${"https://www.youtube.com/feed/trending?bp=6gQJRkVleHBsb3Jl"}")
                self.explore()
            case 2:
                print(f"You Choosen: Shopping ${"https://www.youtube.com/channel/UCkYQyvc_i9hXEo4xic9Hh2g"}")
                self.explore()
            case 3:
                print(f"You Choosen: Music ${"https://www.youtube.com/channel/UC-9-kyTW8ZkZNDHQJ6FgpwQ"}")
                self.explore()
            case 4:
                print(f"You Choosen: Films ${"https://www.youtube.com/feed/storefront?bp=ogUCKAI%3D"}")
                self.explore()
            case 5:
                print(f"You Choosen: Live ${"https://www.youtube.com/channel/UC4R8DWoMoI7CAwX8_LjQHig"}")
                self.explore()
            case 6:
                print(f"You Choosen: Podcasts ${"https://www.youtube.com/podcasts"}")
                self.explore()
            case 7:
                print("Returned to Main Menu")
                self.main()
            case _:
                print("Invalid Option...!")
        print("*"*150)

    def more(self):
        print("*"*150)
        list=[f"YouTube Premium ${"https://www.youtube.com/premium"} ",
              f"YouTube Studio ${"https://studio.youtube.com/"} ",
              f"YouTube Music ${"https://music.youtube.com/"} ",
              f"YouTube Kids ${"https://www.youtubekids.com/?source=youtube_web"} "]
        for i in list:
            print("i")
        print("*"*150)
        self.main()
    
    @staticmethod
    def exit():
        return print('*'*90,"Thank You",'*'*90)

# Obj=youtube("Balaram",934763098,"balaram@gmail.com","Balaram@21","03-05-2001")
Obj1=youtube("Ram",934763098,"balaram@gmail.com","Balaram@21","03-05-2001")

# %%
# Youtube demo with Login:

from datetime import datetime
import re
class youtube:
    App_Name="Youtube"
    App_Owner="Google"
    App_Published="2005"
    
    User_details={}
    User_Id=2024000

    def __init__(self):
        self.User_Id+=1
        # self.main()
        self.view()

    def register(self):
        print("*"*150)
        user_name=input("Enter Username:")
        pattern1 = re.compile(r'^[a-zA-Z0-9_]{3,20}$')
        match1 =re.search(pattern1,user_name)
        if bool(match1):
            user_mobile=input("Enter Mobile Number")
            pattern3=re.compile(r'^[6-9]\d{9}$')
            match3=re.search(pattern3,user_mobile)
            if bool(match3):
                user_email=input("Enter Email Id")
                pattern2=re.compile(r'^[\w.-]+@[a-zA-Z\d.-]+\.[a-zA-Z]{2,}$')
                match2=re.search(pattern2,user_email)
                if bool(match2):
                    user_pwd=input("Enter Password")
                    pattern= re.compile(r'^(?=.*[A-Z])(?=.*[a-z])(?=.*\d)(?=.*[@$!%*?&])[A-Za-z\d@$!%*?&]{8,}$')
                    match = re.search(pattern,user_pwd)
                    if bool(match):
                        user_dob=input("Enter Date of Birth")
                    else:
                        print("Minimum 8 characters, At least one uppercase letter, At least one lowercase letter, At least one digit, At least one special character")
                        self.register()
                else:
                    print("Enter Correct Form of Email Id")
                    self.register()
            else:
                print("Enter Correct Mobile")
                self.register()
        else:
            print("Username Must be letters and Number Combination")
            self.register()

        print("Registered Successfully...!")
        print("*"*150)
        Object = {"user_name":user_name,"user_mobile":user_mobile,"user_email":user_email,"user_pwd":user_pwd,"user_dob":user_dob}
        self.concat_user_details(self.User_Id,Object)
        print("Login User...!")
        print("*"*150)
        self.login(self)
        print("*"*150)
        

    def view(self):
        print('*'*150)
        print("1.Register \n2.Login \n3.Exit")
        n= int(input("If Your New Reigter or Login"))
        match n:
            case 1:
                print("You Choosen: Register")
                self.register()
            case 2:
                print("You Choosen: Login")
                self.login(self)
            case 3:
                print("You Choosen: Exit")
                self.exit()
            case _:
                print("Invalid Option...!")
        print('*'*150)


    @classmethod
    def concat_user_details(cls,user_id,Obj):
        cls.User_details[user_id]= Obj
        # print(cls.User_details[user_id].__dict__)
        # print(cls.User_details)
    
    @classmethod
    def login(cls,self):
        user = input("Enter User Name:")
        if user == cls.User_details[cls.User_Id][self.user_name.value()]:
            Pwd = input("Enter Password:")
            if Pwd == cls.User_details[cls.User_Id][self.user_pwd.value()]:
                print("Login Success !")
                self.main()
            else:
                print("Enter Valid Password!")
                self.login(self)
        else:
            print("Enter Valid Username !")
            self.login(self)

    def main(self):
        print('*'*90,f'Welcome Back  {self.user_name} ❤️','*'*90)
        items=["1. Home","2. Subscriptions","3. Profile","4. Explore","5. More From Youtube","6. Exit"]
        for i in items:
            print(i)
        print("*"*210)
        n = int(input("Choose Your Option:"))
        match n:
            case 1:
                print("You Choosen: Home")
                self.home()
            case 2:
                print("You Choosen: Subscriptions")
                self.Subscription()
            case 3:
                print("You Choosen: Profile")
                self.profile()
            case 4:
                print("You Choosen: Explore")
                self.explore()
            case 5:
                print("You Choosen: More From Youtube")
                self.more()
            case 6:
                print("You Choosen: Exit")
                self.exit()
            case _:
                print("Invalid Option...!")
                self.main()
    
    def home(self):
        print("*"*150)
        Videos=[f"Sirivennala - Lyrical Video | SSR | Telugu {"https://www.youtube.com/watch?v=-19EvIcr9ZA&list=TLPQMDMwMTIwMjTcRGiwPFERLA&index=1&pp=gAQBiAQB8AUB"}",
                f"Hi Nanna:Samayama Lyrical Video | Telugu {"https://www.youtube.com/watch?v=8I9v8yaaknM&list=TLPQMDMwMTIwMjTcRGiwPFERLA&index=2&pp=gAQBiAQB8AUB"}",
                f"Neetho Unte Chalu - Video Song | Telugu {"https://www.youtube.com/watch?v=o19q-7-nIyA&list=TLPQMDMwMTIwMjTcRGiwPFERLA&index=3&pp=gAQBiAQB8AUB"}",
                f"Hi Nanna:Ammaadi(lyrical Video) | Telugu {"https://www.youtube.com/watch?v=uQyUcknlZq0&list=TLPQMDMwMTIwMjTcRGiwPFERLA&index=4&pp=gAQBiAQB8AUB"}",
                f"Gang Leader - Hoyna Hoyna Video | Telugu {"https://www.youtube.com/watch?v=91EzD9VgwGk&list=TLPQMDMwMTIwMjTcRGiwPFERLA&index=5&pp=gAQBiAQB8AUB"}",
                f"Rise of Shyam - Video Song | SSR | Telugu {"https://www.youtube.com/watch?v=60P5xR4GxvE&list=TLPQMDMwMTIwMjTcRGiwPFERLA&index=6&pp=gAQBiAQB8AUB"}",
                f"Evvadikevvadu Banisa Video | KGF | Telugu {"https://www.youtube.com/watch?v=ifwEyWSRrUw&list=TLPQMDMwMTIwMjTcRGiwPFERLA&index=7&pp=gAQBiAQB8AUB"}",
                f"Akaashame Nee Haddhu Ra ! Lyric | Telugu {"https://www.youtube.com/watch?v=9zOIUpJLVps&list=TLPQMDMwMTIwMjTcRGiwPFERLA&index=8&pp=gAQBiAQB8AUB"}",
                f"Dum Masala Lyrical Song | GK | Telugu {"https://www.youtube.com/watch?v=uFpDexeZsG8&list=TLPQMDMwMTIwMjTcRGiwPFERLA&index=9&pp=gAQBiAQB8AUB"}"]
        
        for i in Videos:
            print(i)
        print('*'*150)
        self.main()
    
    def Subscription(self):
        print("*"*150)
        Sub=[f"Apna College {"https://www.youtube.com/@ApnaCollegeOfficial"}",
             f"ForntLineMedia {"https://www.youtube.com/@Frontlinesmedia"}",
             f"Neeraj Walia {"https://www.youtube.com/@ezsnippat"}",
             f"MAHARAJA KITCHEN {"https://www.youtube.com/@MAHARAJAKITCHEN07"}",
             f"$4Visions {"https://www.youtube.com/@4visions270"}",
             f"PrepInsta {"https://www.youtube.com/@PrepInsta"}",
             f"CM Concepts {"https://www.youtube.com/@chauhan_maheshh"}"]
        for i in Sub:
            print("Your Subscriptions:")
            print(i)
        print("*"*150)
        self.main()
    
    @classmethod
    def profile(cls):
        print("*"*150)
        list=cls.User_details[cls.User_Id].__dict__.items()
        for i in list:
            print(i)
        print("*"*150)
    
    def explore(self):
        print("*"*150)
        options=["1. Trending","2. Shopping","3. Music","4. Films","5. Live", "6. Podcasts","7. Return to Menu"]
        for i in options:
            print(i)
        n=int(input("Enter Your Choice:"))
        match n:
            case 1:
                print(f"You Choosen: Trending {"https://www.youtube.com/feed/trending?bp=6gQJRkVleHBsb3Jl"}")
                self.explore()
            case 2:
                print(f"You Choosen: Shopping {"https://www.youtube.com/channel/UCkYQyvc_i9hXEo4xic9Hh2g"}")
                self.explore()
            case 3:
                print(f"You Choosen: Music {"https://www.youtube.com/channel/UC-9-kyTW8ZkZNDHQJ6FgpwQ"}")
                self.explore()
            case 4:
                print(f"You Choosen: Films {"https://www.youtube.com/feed/storefront?bp=ogUCKAI%3D"}")
                self.explore()
            case 5:
                print(f"You Choosen: Live {"https://www.youtube.com/channel/UC4R8DWoMoI7CAwX8_LjQHig"}")
                self.explore()
            case 6:
                print(f"You Choosen: Podcasts {"https://www.youtube.com/podcasts"}")
                self.explore()
            case 7:
                print("Returned to Main Menu")
                self.main()
            case _:
                print("Invalid Option...!")
        print("*"*150)

    def more(self):
        print("*"*150)
        list=[f"YouTube Premium {"https://www.youtube.com/premium"} ",
              f"YouTube Studio {"https://studio.youtube.com/"} ",
              f"YouTube Music {"https://music.youtube.com/"} ",
              f"YouTube Kids {"https://www.youtubekids.com/?source=youtube_web"} "]
        for i in list:
            print("i")
        print("*"*150)
        self.main()
    
    @staticmethod
    def exit():
        return print('*'*90,"Thank You",'*'*90)

youtube()
# Obj=youtube("Balaram",934763098,"balaram@gmail.com","Balaram@21","03-05-2001")
# print(youtube.__dict__)
# Out:
# ******************************************************************************************************************************************************
# 1.Register
# 2.Login
# 3.Exit
# You Choosen: Register
# ******************************************************************************************************************************************************
# Minimum 8 characters, At least one uppercase letter, At least one lowercase letter, At least one digit, At least one special character
# ******************************************************************************************************************************************************
# Username Must be letters and Number Combination
# ******************************************************************************************************************************************************
# Username Must be letters and Number Combination
# ...
